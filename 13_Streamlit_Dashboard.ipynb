# %% [markdown]
# <a href="https://colab.research.google.com/github/samreenfathima18/Guvi-Final-project/blob/main/13_Streamlit_Dashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q streamlit
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 97.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 101.6 MB/s eta 0:00:00

# %%
# %%writefile app.py
import streamlit as st

st.set_page_config(
    page_title="Enterprise Retail Intelligence",
    page_icon="📊",
    layout="wide"
)

st.title("📊 Enterprise Retail Intelligence")

st.markdown("""
### Demand Forecasting & Inventory Optimization

Welcome to the Enterprise Retail Intelligence Dashboard.

This project includes:

- 📈 Sales Forecasting
- 📦 Inventory Optimization
- 🏆 Model Comparison
- 📊 Business Insights

**Best Model:** LightGBM
""")

st.success("Project Completed Successfully!")
# Out:
# Overwriting app.py

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
RESULTS_PATH = "/content/drive/MyDrive/Enterprise_Retail_Intelligence/results/"
OUTPUTS_PATH = "/content/drive/MyDrive/Enterprise_Retail_Intelligence/outputs/"
MODELS_PATH = "/content/drive/MyDrive/Enterprise_Retail_Intelligence/models/"

# %%
comparison = pd.read_csv(
    RESULTS_PATH + "model_comparison.csv"
)

# %%
inventory = pd.read_csv(
    RESULTS_PATH + "inventory_recommendations.csv"
)

# %%
predictions = pd.read_csv(
    RESULTS_PATH + "LightGBM_predictions.csv"
)
